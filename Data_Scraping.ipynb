# %%
import os
import requests
import zipfile
from io import BytesIO

# Format and download URL mapping
formats = {
    "ODI": "https://cricsheet.org/downloads/odis_json.zip",
    "T20": "https://cricsheet.org/downloads/t20s_json.zip",
    "Test": "https://cricsheet.org/downloads/tests_json.zip",
    "IPL": "https://cricsheet.org/downloads/ipl_json.zip"
}

BASE_DIR = "cricsheet_data"
os.makedirs(BASE_DIR, exist_ok=True)

for fmt, url in formats.items():
    print(f"⬇️ Downloading {fmt} data from {url}")
    response = requests.get(url)

    if response.status_code == 200:
        zip_path = os.path.join(BASE_DIR, f"{fmt}.zip")
        with open(zip_path, "wb") as f:
            f.write(response.content)

        # Extract ZIP
        extract_dir = os.path.join(BASE_DIR, fmt)
        os.makedirs(extract_dir, exist_ok=True)
        with zipfile.ZipFile(BytesIO(response.content)) as z:
            z.extractall(extract_dir)

        print(f"✅ Extracted {fmt} JSONs to {extract_dir}")
    else:
        print(f"❌ Failed to download {fmt} data. Status: {response.status_code}")
# Out:
# ⬇️ Downloading ODI data from https://cricsheet.org/downloads/odis_json.zip
# ✅ Extracted ODI JSONs to cricsheet_data\ODI
# ⬇️ Downloading T20 data from https://cricsheet.org/downloads/t20s_json.zip
# ✅ Extracted T20 JSONs to cricsheet_data\T20
# ⬇️ Downloading Test data from https://cricsheet.org/downloads/tests_json.zip
# ✅ Extracted Test JSONs to cricsheet_data\Test
# ⬇️ Downloading IPL data from https://cricsheet.org/downloads/ipl_json.zip
# ✅ Extracted IPL JSONs to cricsheet_data\IPL

# %%
# step2_parse_cricsheet.py
# Parse extracted Cricsheet JSONs

import os
import json
import pandas as pd

BASE_DIR = "cricsheet_data"  # contains Test/, ODI/, T20/, IPL/
INPUT_DIRS = {
    "Test": os.path.join(BASE_DIR, "Test"),
    "ODI":  os.path.join(BASE_DIR, "ODI"),
    "T20":  os.path.join(BASE_DIR, "T20"),
    "IPL":  os.path.join(BASE_DIR, "IPL"),
}
OUTPUT_DIR = os.path.join(BASE_DIR, "processed")
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Storage
detailed_data = {"Test": [], "ODI": [], "T20": [], "IPL": []}

def extract_first_wicket_player_out(delivery: dict) -> str:
    """Return first wicket's player_out if any, else 'None' (matches friend's logic)."""
    wickets = delivery.get("wickets")
    if isinstance(wickets, list) and len(wickets) > 0:
        return wickets[0].get("player_out", "None")
    return "None"

def parse_json_file(filepath: str, target_match_type: str):
    """Parse a single Cricsheet JSON and append delivery-level rows for the target match type."""
    try:
        with open(filepath, "r", encoding="utf-8", errors="ignore") as f:
            match_data = json.load(f)
    except json.JSONDecodeError as je:
        print(f" *** JSONDecodeError in {filepath}: {je}")
        return
    except Exception as er:
        print(f" error reading json {filepath}: {er}")
        return

    match_info = match_data.get("info", {})
    teams = match_info.get("teams", [])

    # stable match_id from filename + match_date from info.dates[0]
    match_id = os.path.splitext(os.path.basename(filepath))[0]
    match_date = None
    dates = match_info.get("dates") or []
    if isinstance(dates, list) and dates:
        match_date = str(dates[0])

    match_details = {
        "match_id": match_id,
        "match_date": match_date,
        "match_type": match_info.get("match_type"),
        "season": match_info.get("season"),
        "city": match_info.get("city"),
        "venue": match_info.get("venue"),
        "toss_winner": match_info.get("toss", {}).get("winner"),
        "toss_decision": match_info.get("toss", {}).get("decision"),
        "winner": match_info.get("outcome", {}).get("winner", "draw"),
        "player_of_match": ", ".join(match_info.get("player_of_match", [])),
        "teams": ", ".join(teams),
    }

    for inning in match_data.get("innings", []):
        team = inning.get("team", "Unknown")
        for over in inning.get("overs", []):
            over_number = over.get("over")
            for delivery in over.get("deliveries", []):
                delivery_row = {
                    "team": team,
                    "over": over_number,
                    "batter": delivery.get("batter"),
                    "bowler": delivery.get("bowler"),
                    "non_striker": delivery.get("non_striker"),
                    "runs_batter": delivery.get("runs", {}).get("batter", 0),
                    "runs_extras": delivery.get("runs", {}).get("extras", 0),
                    "runs_total": delivery.get("runs", {}).get("total", 0),
                    "wicket": extract_first_wicket_player_out(delivery),
                }
                detailed_data[target_match_type].append({**match_details, **delivery_row})

def process_format(match_type: str, input_dir: str):
    """Walk the format folder and parse all .json files."""
    if not os.path.isdir(input_dir):
        print(f"❌ Missing folder for {match_type}: {input_dir}")
        return

    file_count = 0
    print(f"\nProcessing {match_type} JSONs from: {input_dir}")
    for root, _, files in os.walk(input_dir):
        for name in files:
            if name.lower().endswith(".json"):
                file_count += 1
                parse_json_file(os.path.join(root, name), match_type)

    print(f"✅ {match_type}: scanned {file_count} files, rows so far: {len(detailed_data[match_type])}")

# Run all four formats
for mt, in_dir in INPUT_DIRS.items():
    process_format(mt, in_dir)

# create DataFrames and write CSVs (under /processed)
test_df = pd.DataFrame(detailed_data.get("Test", []))
odi_df  = pd.DataFrame(detailed_data.get("ODI", []))
t20_df  = pd.DataFrame(detailed_data.get("T20", []))
ipl_df  = pd.DataFrame(detailed_data.get("IPL", []))

test_csv = os.path.join(OUTPUT_DIR, "test.csv")
odi_csv  = os.path.join(OUTPUT_DIR, "ODI.csv")
t20_csv  = os.path.join(OUTPUT_DIR, "T20.csv")
ipl_csv  = os.path.join(OUTPUT_DIR, "IPL.csv")

test_df.to_csv(test_csv, index=False)
odi_df.to_csv(odi_csv, index=False)
t20_df.to_csv(t20_csv, index=False)
ipl_df.to_csv(ipl_csv, index=False)

print("\n📁 Output CSVs written to:", OUTPUT_DIR)
# Out:
# Processing Test JSONs from: cricsheet_data\Test
# ✅ Test: scanned 880 files, rows so far: 1701764
#
# Processing ODI JSONs from: cricsheet_data\ODI
# ✅ ODI: scanned 3019 files, rows so far: 1598807
#
# Processing T20 JSONs from: cricsheet_data\T20
# ✅ T20: scanned 4673 files, rows so far: 1058045
#
# Processing IPL JSONs from: cricsheet_data\IPL
# ✅ IPL: scanned 1169 files, rows so far: 278205
#
# 📁 Output CSVs written to: cricsheet_data\processed

# %%
# ---- Print small heads like the friend’s script ----
if not test_df.empty:
    print("\n Test DataFrame:")
    print(test_df.head())
if not odi_df.empty:
    print("\n ODI DataFrame:")
    print(odi_df.head())
if not t20_df.empty:
    print("\n T20 DataFrame:")
    print(t20_df.head())
if not ipl_df.empty:
    print("\n IPL DataFrame:")
    print(ipl_df.head())
# Out:
#  Test DataFrame:
#   match_id  match_date match_type   season   city  \
# 0  1000851  2016-11-03       Test  2016/17  Perth
# 1  1000851  2016-11-03       Test  2016/17  Perth
# 2  1000851  2016-11-03       Test  2016/17  Perth
# 3  1000851  2016-11-03       Test  2016/17  Perth
# 4  1000851  2016-11-03       Test  2016/17  Perth
#
#                                           venue   toss_winner toss_decision  \
# 0  Western Australia Cricket Association Ground  South Africa           bat
# 1  Western Australia Cricket Association Ground  South Africa           bat
# 2  Western Australia Cricket Association Ground  South Africa           bat
# 3  Western Australia Cricket Association Ground  South Africa           bat
# 4  Western Australia Cricket Association Ground  South Africa           bat
#
#          winner player_of_match                    teams          team  over  \
# 0  South Africa        K Rabada  Australia, South Africa  South Africa     0
# 1  South Africa        K Rabada  Australia, South Africa  South Africa     0
# 2  South Africa        K Rabada  Australia, South Africa  South Africa     0
# 3  South Africa        K Rabada  Australia, South Africa  South Africa     0
# 4  South Africa        K Rabada  Australia, South Africa  South Africa     0
#
#     batter    bowler non_striker  runs_batter  runs_extras  runs_total  \
# 0  SC Cook  MA Starc     D Elgar            0            0           0
# 1  SC Cook  MA Starc     D Elgar            0            0           0
# 2  SC Cook  MA Starc     D Elgar            0            0           0
# 3  SC Cook  MA Starc     D Elgar            0            0           0
# 4  HM Amla  MA Starc     D Elgar            0            0           0
#
#     wicket
# 0     None
# 1     None
# 2     None
# 3  SC Cook
# 4     None
#
#  ODI DataFrame:
#   match_id  match_date match_type   season      city  \
# 0  1000887  2017-01-13        ODI  2016/17  Brisbane
# 1  1000887  2017-01-13        ODI  2016/17  Brisbane
# 2  1000887  2017-01-13        ODI  2016/17  Brisbane
# 3  1000887  2017-01-13        ODI  2016/17  Brisbane
# 4  1000887  2017-01-13        ODI  2016/17  Brisbane
#
#                                     venue toss_winner toss_decision  \
# 0  Brisbane Cricket Ground, Woolloongabba   Australia           bat
# 1  Brisbane Cricket Ground, Woolloongabba   Australia           bat
# 2  Brisbane Cricket Ground, Woolloongabba   Australia           bat
# 3  Brisbane Cricket Ground, Woolloongabba   Australia           bat
# 4  Brisbane Cricket Ground, Woolloongabba   Australia           bat
#
#       winner player_of_match                teams       team  over     batter  \
# 0  Australia         MS Wade  Australia, Pakistan  Australia     0  DA Warner
# 1  Australia         MS Wade  Australia, Pakistan  Australia     0  DA Warner
# 2  Australia         MS Wade  Australia, Pakistan  Australia     0  DA Warner
# 3  Australia         MS Wade  Australia, Pakistan  Australia     0  DA Warner
# 4  Australia         MS Wade  Australia, Pakistan  Australia     0  DA Warner
#
#           bowler non_striker  runs_batter  runs_extras  runs_total wicket
# 0  Mohammad Amir     TM Head            0            0           0   None
# 1  Mohammad Amir     TM Head            0            0           0   None
# 2  Mohammad Amir     TM Head            0            0           0   None
# 3  Mohammad Amir     TM Head            0            0           0   None
# 4  Mohammad Amir     TM Head            0            1           1   None
#
#  T20 DataFrame:
#   match_id  match_date match_type   season  city                     venue  \
# 0  1001349  2017-02-17        T20  2016/17  None  Melbourne Cricket Ground
# 1  1001349  2017-02-17        T20  2016/17  None  Melbourne Cricket Ground
# 2  1001349  2017-02-17        T20  2016/17  None  Melbourne Cricket Ground
# 3  1001349  2017-02-17        T20  2016/17  None  Melbourne Cricket Ground
# 4  1001349  2017-02-17        T20  2016/17  None  Melbourne Cricket Ground
#
#   toss_winner toss_decision     winner player_of_match                 teams  \
# 0   Sri Lanka         field  Sri Lanka   DAS Gunaratne  Australia, Sri Lanka
# 1   Sri Lanka         field  Sri Lanka   DAS Gunaratne  Australia, Sri Lanka
# 2   Sri Lanka         field  Sri Lanka   DAS Gunaratne  Australia, Sri Lanka
# 3   Sri Lanka         field  Sri Lanka   DAS Gunaratne  Australia, Sri Lanka
# 4   Sri Lanka         field  Sri Lanka   DAS Gunaratne  Australia, Sri Lanka
#
#         team  over     batter      bowler non_striker  runs_batter  \
# 0  Australia     0   AJ Finch  SL Malinga   M Klinger            0
# 1  Australia     0   AJ Finch  SL Malinga   M Klinger            0
# 2  Australia     0   AJ Finch  SL Malinga   M Klinger            1
# 3  Australia     0  M Klinger  SL Malinga    AJ Finch            2
# 4  Australia     0  M Klinger  SL Malinga    AJ Finch            0
#
#    runs_extras  runs_total wicket
# 0            0           0   None
# 1            0           0   None
# 2            0           1   None
# 3            0           2   None
# 4            0           0   None
#
#  IPL DataFrame:
#   match_id  match_date match_type season       city  \
# 0  1082591  2017-04-05        T20   2017  Hyderabad
# 1  1082591  2017-04-05        T20   2017  Hyderabad
# 2  1082591  2017-04-05        T20   2017  Hyderabad
# 3  1082591  2017-04-05        T20   2017  Hyderabad
# 4  1082591  2017-04-05        T20   2017  Hyderabad
#
#                                        venue                  toss_winner  \
# 0  Rajiv Gandhi International Stadium, Uppal  Royal Challengers Bangalore
# 1  Rajiv Gandhi International Stadium, Uppal  Royal Challengers Bangalore
# 2  Rajiv Gandhi International Stadium, Uppal  Royal Challengers Bangalore
# 3  Rajiv Gandhi International Stadium, Uppal  Royal Challengers Bangalore
# 4  Rajiv Gandhi International Stadium, Uppal  Royal Challengers Bangalore
#
#   toss_decision               winner player_of_match  \
# 0         field  Sunrisers Hyderabad    Yuvraj Singh
# 1         field  Sunrisers Hyderabad    Yuvraj Singh
# 2         field  Sunrisers Hyderabad    Yuvraj Singh
# 3         field  Sunrisers Hyderabad    Yuvraj Singh
# 4         field  Sunrisers Hyderabad    Yuvraj Singh
#
#                                               teams                 team  \
# 0  Sunrisers Hyderabad, Royal Challengers Bangalore  Sunrisers Hyderabad
# 1  Sunrisers Hyderabad, Royal Challengers Bangalore  Sunrisers Hyderabad
# 2  Sunrisers Hyderabad, Royal Challengers Bangalore  Sunrisers Hyderabad
# 3  Sunrisers Hyderabad, Royal Challengers Bangalore  Sunrisers Hyderabad
# 4  Sunrisers Hyderabad, Royal Challengers Bangalore  Sunrisers Hyderabad
#
#    over     batter    bowler non_striker  runs_batter  runs_extras  \
# 0     0  DA Warner  TS Mills    S Dhawan            0            0
# 1     0  DA Warner  TS Mills    S Dhawan            0            0
# 2     0  DA Warner  TS Mills    S Dhawan            4            0
# 3     0  DA Warner  TS Mills    S Dhawan            0            0
# 4     0  DA Warner  TS Mills    S Dhawan            0            2
#
#    runs_total wicket
# 0           0   None
# 1           0   None
# 2           4   None
# 3           0   None
# 4           2   None
